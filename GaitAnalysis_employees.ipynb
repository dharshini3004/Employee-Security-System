# %%
import numpy as np
import pandas as pd

#getting total number of features

features = list()
with open('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('Total Features: {}'.format(len(features)))
# Out:
# Total Features: 561

# %% [markdown]
# 1.   Importing libraries:
#
# *   Numpy
# *   Pandas
#
# 2. Getting the total number of features.

# %%
features
# Out:
# ['tBodyAcc-mean()-X',
#  'tBodyAcc-mean()-Y',
#  'tBodyAcc-mean()-Z',
#  'tBodyAcc-std()-X',
#  'tBodyAcc-std()-Y',
#  'tBodyAcc-std()-Z',
#  'tBodyAcc-mad()-X',
#  'tBodyAcc-mad()-Y',
#  'tBodyAcc-mad()-Z',
#  'tBodyAcc-max()-X',
#  'tBodyAcc-max()-Y',
#  'tBodyAcc-max()-Z',
#  'tBodyAcc-min()-X',
#  'tBodyAcc-min()-Y',
#  'tBodyAcc-min()-Z',
#  'tBodyAcc-sma()',
#  'tBodyAcc-energy()-X',
#  'tBodyAcc-energy()-Y',
#  'tBodyAcc-energy()-Z',
#  'tBodyAcc-iqr()-X',
#  'tBodyAcc-iqr()-Y',
#  'tBodyAcc-iqr()-Z',
#  'tBodyAcc-entropy()-X',
#  'tBodyAcc-entropy()-Y',
#  'tBodyAcc-entropy()-Z',
#  'tBodyAcc-arCoeff()-X,1',
#  'tBodyAcc-arCoeff()-X,2',
#  'tBodyAcc-arCoeff()-X,3',
#  'tBodyAcc-arCoeff()-X,4',
#  'tBodyAcc-arCoeff()-Y,1',
#  'tBodyAcc-arCoeff()-Y,2',
#  'tBodyAcc-arCoeff()-Y,3',
#  'tBodyAcc-arCoeff()-Y,4',
#  'tBodyAcc-arCoeff()-Z,1',
#  'tBodyAcc-arCoeff()-Z,2',
#  'tBodyAcc-arCoeff()-Z,3',
#  'tBodyAcc-arCoeff()-Z,4',
#  'tBodyAcc-correlation()-X,Y',
#  'tBodyAcc-correlation()-X,Z',
#  'tBodyAcc-correlation()-Y,Z',
#  'tGravityAcc-mean()-X',
#  'tGravityAcc-mean()-Y',
#  'tGravityAcc-mean()-Z',
#  'tGravityAcc-std()-X',
#  'tGravityAcc-std()-Y',
#  'tGravityAcc-std()-Z',
#  'tGravityAcc-mad()-X',
#  'tGravityAcc-mad()-Y',
#  'tGravityAcc-mad()-Z',
#  'tGravityAcc-max()-X',
#  'tGravityAcc-max()-Y',
#  'tGravityAcc-max()-Z',
#  'tGravityAcc-min()-X',
#  'tGravityAcc-min()-Y',
#  'tGravityAcc-min()-Z',
#  'tGravityAcc-sma()',
#  'tGravityAcc-energy()-X',
#  'tGravityAcc-energy()-Y',
#  'tGravityAcc-energy()-Z',
#  'tGravityAcc-iqr()-X',
#  'tGravityAcc-iqr()-Y',
#  'tGravityAcc-iqr()-Z',
#  'tGravityAcc-entropy()-X',
#  'tGravityAcc-entropy()-Y',
#  'tGravityAcc-entropy()-Z',
#  'tGravityAcc-arCoeff()-X,1',
#  'tGravityAcc-arCoeff()-X,2',
#  'tGravityAcc-arCoeff()-X,3',
#  'tGravityAcc-arCoeff()-X,4',
#  'tGravityAcc-arCoeff()-Y,1',
#  'tGravityAcc-arCoeff()-Y,2',
#  'tGravityAcc-arCoeff()-Y,3',
#  'tGravityAcc-arCoeff()-Y,4',
#  'tGravityAcc-arCoeff()-Z,1',
#  'tGravityAcc-arCoeff()-Z,2',
#  'tGravityAcc-arCoeff()-Z,3',
#  'tGravityAcc-arCoeff()-Z,4',
#  'tGravityAcc-correlation()-X,Y',
#  'tGravityAcc-correlation()-X,Z',
#  'tGravityAcc-correlation()-Y,Z',
#  'tBodyAccJerk-mean()-X',
#  'tBodyAccJerk-mean()-Y',
#  'tBodyAccJerk-mean()-Z',
#  'tBodyAccJerk-std()-X',
#  'tBodyAccJerk-std()-Y',
#  'tBodyAccJerk-std()-Z',
#  'tBodyAccJerk-mad()-X',
#  'tBodyAccJerk-mad()-Y',
#  'tBodyAccJerk-mad()-Z',
#  'tBodyAccJerk-max()-X',
#  'tBodyAccJerk-max()-Y',
#  'tBodyAccJerk-max()-Z',
#  'tBodyAccJerk-min()-X',
#  'tBodyAccJerk-min()-Y',
#  'tBodyAccJerk-min()-Z',
#  'tBodyAccJerk-sma()',
#  'tBodyAccJerk-energy()-X',
#  'tBodyAccJerk-energy()-Y',
#  'tBodyAccJerk-energy()-Z',
#  'tBodyAccJerk-iqr()-X',
#  'tBodyAccJerk-iqr()-Y',
#  'tBodyAccJerk-iqr()-Z',
#  'tBodyAccJerk-entropy()-X',
#  'tBodyAccJerk-entropy()-Y',
#  'tBodyAccJerk-entropy()-Z',
#  'tBodyAccJerk-arCoeff()-X,1',
#  'tBodyAccJerk-arCoeff()-X,2',
#  'tBodyAccJerk-arCoeff()-X,3',
#  'tBodyAccJerk-arCoeff()-X,4',
#  'tBodyAccJerk-arCoeff()-Y,1',
#  'tBodyAccJerk-arCoeff()-Y,2',
#  'tBodyAccJerk-arCoeff()-Y,3',
#  'tBodyAccJerk-arCoeff()-Y,4',
#  'tBodyAccJerk-arCoeff()-Z,1',
#  'tBodyAccJerk-arCoeff()-Z,2',
#  'tBodyAccJerk-arCoeff()-Z,3',
#  'tBodyAccJerk-arCoeff()-Z,4',
#  'tBodyAccJerk-correlation()-X,Y',
#  'tBodyAccJerk-correlation()-X,Z',
#  'tBodyAccJerk-correlation()-Y,Z',
#  'tBodyGyro-mean()-X',
#  'tBodyGyro-mean()-Y',
#  'tBodyGyro-mean()-Z',
#  'tBodyGyro-std()-X',
#  'tBodyGyro-std()-Y',
#  'tBodyGyro-std()-Z',
#  'tBodyGyro-mad()-X',
#  'tBodyGyro-mad()-Y',
#  'tBodyGyro-mad()-Z',
#  'tBodyGyro-max()-X',
#  'tBodyGyro-max()-Y',
#  'tBodyGyro-max()-Z',
#  'tBodyGyro-min()-X',
#  'tBodyGyro-min()-Y',
#  'tBodyGyro-min()-Z',
#  'tBodyGyro-sma()',
#  'tBodyGyro-energy()-X',
#  'tBodyGyro-energy()-Y',
#  'tBodyGyro-energy()-Z',
#  'tBodyGyro-iqr()-X',
#  'tBodyGyro-iqr()-Y',
#  'tBodyGyro-iqr()-Z',
#  'tBodyGyro-entropy()-X',
#  'tBodyGyro-entropy()-Y',
#  'tBodyGyro-entropy()-Z',
#  'tBodyGyro-arCoeff()-X,1',
#  'tBodyGyro-arCoeff()-X,2',
#  'tBodyGyro-arCoeff()-X,3',
#  'tBodyGyro-arCoeff()-X,4',
#  'tBodyGyro-arCoeff()-Y,1',
#  'tBodyGyro-arCoeff()-Y,2',
#  'tBodyGyro-arCoeff()-Y,3',
#  'tBodyGyro-arCoeff()-Y,4',
#  'tBodyGyro-arCoeff()-Z,1',
#  'tBodyGyro-arCoeff()-Z,2',
#  'tBodyGyro-arCoeff()-Z,3',
#  'tBodyGyro-arCoeff()-Z,4',
#  'tBodyGyro-correlation()-X,Y',
#  'tBodyGyro-correlation()-X,Z',
#  'tBodyGyro-correlation()-Y,Z',
#  'tBodyGyroJerk-mean()-X',
#  'tBodyGyroJerk-mean()-Y',
#  'tBodyGyroJerk-mean()-Z',
#  'tBodyGyroJerk-std()-X',
#  'tBodyGyroJerk-std()-Y',
#  'tBodyGyroJerk-std()-Z',
#  'tBodyGyroJerk-mad()-X',
#  'tBodyGyroJerk-mad()-Y',
#  'tBodyGyroJerk-mad()-Z',
#  'tBodyGyroJerk-max()-X',
#  'tBodyGyroJerk-max()-Y',
#  'tBodyGyroJerk-max()-Z',
#  'tBodyGyroJerk-min()-X',
#  'tBodyGyroJerk-min()-Y',
#  'tBodyGyroJerk-min()-Z',
#  'tBodyGyroJerk-sma()',
#  'tBodyGyroJerk-energy()-X',
#  'tBodyGyroJerk-energy()-Y',
#  'tBodyGyroJerk-energy()-Z',
#  'tBodyGyroJerk-iqr()-X',
#  'tBodyGyroJerk-iqr()-Y',
#  'tBodyGyroJerk-iqr()-Z',
#  'tBodyGyroJerk-entropy()-X',
#  'tBodyGyroJerk-entropy()-Y',
#  'tBodyGyroJerk-entropy()-Z',
#  'tBodyGyroJerk-arCoeff()-X,1',
#  'tBodyGyroJerk-arCoeff()-X,2',
#  'tBodyGyroJerk-arCoeff()-X,3',
#  'tBodyGyroJerk-arCoeff()-X,4',
#  'tBodyGyroJerk-arCoeff()-Y,1',
#  'tBodyGyroJerk-arCoeff()-Y,2',
#  'tBodyGyroJerk-arCoeff()-Y,3',
#  'tBodyGyroJerk-arCoeff()-Y,4',
#  'tBodyGyroJerk-arCoeff()-Z,1',
#  'tBodyGyroJerk-arCoeff()-Z,2',
#  'tBodyGyroJerk-arCoeff()-Z,3',
#  'tBodyGyroJerk-arCoeff()-Z,4',
#  'tBodyGyroJerk-correlation()-X,Y',
#  'tBodyGyroJerk-correlation()-X,Z',
#  'tBodyGyroJerk-correlation()-Y,Z',
#  'tBodyAccMag-mean()',
#  'tBodyAccMag-std()',
#  'tBodyAccMag-mad()',
#  'tBodyAccMag-max()',
#  'tBodyAccMag-min()',
#  'tBodyAccMag-sma()',
#  'tBodyAccMag-energy()',
#  'tBodyAccMag-iqr()',
#  'tBodyAccMag-entropy()',
#  'tBodyAccMag-arCoeff()1',
#  'tBodyAccMag-arCoeff()2',
#  'tBodyAccMag-arCoeff()3',
#  'tBodyAccMag-arCoeff()4',
#  'tGravityAccMag-mean()',
#  'tGravityAccMag-std()',
#  'tGravityAccMag-mad()',
#  'tGravityAccMag-max()',
#  'tGravityAccMag-min()',
#  'tGravityAccMag-sma()',
#  'tGravityAccMag-energy()',
#  'tGravityAccMag-iqr()',
#  'tGravityAccMag-entropy()',
#  'tGravityAccMag-arCoeff()1',
#  'tGravityAccMag-arCoeff()2',
#  'tGravityAccMag-arCoeff()3',
#  'tGravityAccMag-arCoeff()4',
#  'tBodyAccJerkMag-mean()',
#  'tBodyAccJerkMag-std()',
#  'tBodyAccJerkMag-mad()',
#  'tBodyAccJerkMag-max()',
#  'tBodyAccJerkMag-min()',
#  'tBodyAccJerkMag-sma()',
#  'tBodyAccJerkMag-energy()',
#  'tBodyAccJerkMag-iqr()',
#  'tBodyAccJerkMag-entropy()',
#  'tBodyAccJerkMag-arCoeff()1',
#  'tBodyAccJerkMag-arCoeff()2',
#  'tBodyAccJerkMag-arCoeff()3',
#  'tBodyAccJerkMag-arCoeff()4',
#  'tBodyGyroMag-mean()',
#  'tBodyGyroMag-std()',
#  'tBodyGyroMag-mad()',
#  'tBodyGyroMag-max()',
#  'tBodyGyroMag-min()',
#  'tBodyGyroMag-sma()',
#  'tBodyGyroMag-energy()',
#  'tBodyGyroMag-iqr()',
#  'tBodyGyroMag-entropy()',
#  'tBodyGyroMag-arCoeff()1',
#  'tBodyGyroMag-arCoeff()2',
#  'tBodyGyroMag-arCoeff()3',
#  'tBodyGyroMag-arCoeff()4',
#  'tBodyGyroJerkMag-mean()',
#  'tBodyGyroJerkMag-std()',
#  'tBodyGyroJerkMag-mad()',
#  'tBodyGyroJerkMag-max()',
#  'tBodyGyroJerkMag-min()',
#  'tBodyGyroJerkMag-sma()',
#  'tBodyGyroJerkMag-energy()',
#  'tBodyGyroJerkMag-iqr()',
#  'tBodyGyroJerkMag-entropy()',
#  'tBodyGyroJerkMag-arCoeff()1',
#  'tBodyGyroJerkMag-arCoeff()2',
#  'tBodyGyroJerkMag-arCoeff()3',
#  'tBodyGyroJerkMag-arCoeff()4',
#  'fBodyAcc-mean()-X',
#  'fBodyAcc-mean()-Y',
#  'fBodyAcc-mean()-Z',
#  'fBodyAcc-std()-X',
#  'fBodyAcc-std()-Y',
#  'fBodyAcc-std()-Z',
#  'fBodyAcc-mad()-X',
#  'fBodyAcc-mad()-Y',
#  'fBodyAcc-mad()-Z',
#  'fBodyAcc-max()-X',
#  'fBodyAcc-max()-Y',
#  'fBodyAcc-max()-Z',
#  'fBodyAcc-min()-X',
#  'fBodyAcc-min()-Y',
#  'fBodyAcc-min()-Z',
#  'fBodyAcc-sma()',
#  'fBodyAcc-energy()-X',
#  'fBodyAcc-energy()-Y',
#  'fBodyAcc-energy()-Z',
#  'fBodyAcc-iqr()-X',
#  'fBodyAcc-iqr()-Y',
#  'fBodyAcc-iqr()-Z',
#  'fBodyAcc-entropy()-X',
#  'fBodyAcc-entropy()-Y',
#  'fBodyAcc-entropy()-Z',
#  'fBodyAcc-maxInds-X',
#  'fBodyAcc-maxInds-Y',
#  'fBodyAcc-maxInds-Z',
#  'fBodyAcc-meanFreq()-X',
#  'fBodyAcc-meanFreq()-Y',
#  'fBodyAcc-meanFreq()-Z',
#  'fBodyAcc-skewness()-X',
#  'fBodyAcc-kurtosis()-X',
#  'fBodyAcc-skewness()-Y',
#  'fBodyAcc-kurtosis()-Y',
#  'fBodyAcc-skewness()-Z',
#  'fBodyAcc-kurtosis()-Z',
#  'fBodyAcc-bandsEnergy()-1,8',
#  'fBodyAcc-bandsEnergy()-9,16',
#  'fBodyAcc-bandsEnergy()-17,24',
#  'fBodyAcc-bandsEnergy()-25,32',
#  'fBodyAcc-bandsEnergy()-33,40',
#  'fBodyAcc-bandsEnergy()-41,48',
#  'fBodyAcc-bandsEnergy()-49,56',
#  'fBodyAcc-bandsEnergy()-57,64',
#  'fBodyAcc-bandsEnergy()-1,16',
#  'fBodyAcc-bandsEnergy()-17,32',
#  'fBodyAcc-bandsEnergy()-33,48',
#  'fBodyAcc-bandsEnergy()-49,64',
#  'fBodyAcc-bandsEnergy()-1,24',
#  'fBodyAcc-bandsEnergy()-25,48',
#  'fBodyAcc-bandsEnergy()-1,8',
#  'fBodyAcc-bandsEnergy()-9,16',
#  'fBodyAcc-bandsEnergy()-17,24',
#  'fBodyAcc-bandsEnergy()-25,32',
#  'fBodyAcc-bandsEnergy()-33,40',
#  'fBodyAcc-bandsEnergy()-41,48',
#  'fBodyAcc-bandsEnergy()-49,56',
#  'fBodyAcc-bandsEnergy()-57,64',
#  'fBodyAcc-bandsEnergy()-1,16',
#  'fBodyAcc-bandsEnergy()-17,32',
#  'fBodyAcc-bandsEnergy()-33,48',
#  'fBodyAcc-bandsEnergy()-49,64',
#  'fBodyAcc-bandsEnergy()-1,24',
#  'fBodyAcc-bandsEnergy()-25,48',
#  'fBodyAcc-bandsEnergy()-1,8',
#  'fBodyAcc-bandsEnergy()-9,16',
#  'fBodyAcc-bandsEnergy()-17,24',
#  'fBodyAcc-bandsEnergy()-25,32',
#  'fBodyAcc-bandsEnergy()-33,40',
#  'fBodyAcc-bandsEnergy()-41,48',
#  'fBodyAcc-bandsEnergy()-49,56',
#  'fBodyAcc-bandsEnergy()-57,64',
#  'fBodyAcc-bandsEnergy()-1,16',
#  'fBodyAcc-bandsEnergy()-17,32',
#  'fBodyAcc-bandsEnergy()-33,48',
#  'fBodyAcc-bandsEnergy()-49,64',
#  'fBodyAcc-bandsEnergy()-1,24',
#  'fBodyAcc-bandsEnergy()-25,48',
#  'fBodyAccJerk-mean()-X',
#  'fBodyAccJerk-mean()-Y',
#  'fBodyAccJerk-mean()-Z',
#  'fBodyAccJerk-std()-X',
#  'fBodyAccJerk-std()-Y',
#  'fBodyAccJerk-std()-Z',
#  'fBodyAccJerk-mad()-X',
#  'fBodyAccJerk-mad()-Y',
#  'fBodyAccJerk-mad()-Z',
#  'fBodyAccJerk-max()-X',
#  'fBodyAccJerk-max()-Y',
#  'fBodyAccJerk-max()-Z',
#  'fBodyAccJerk-min()-X',
#  'fBodyAccJerk-min()-Y',
#  'fBodyAccJerk-min()-Z',
#  'fBodyAccJerk-sma()',
#  'fBodyAccJerk-energy()-X',
#  'fBodyAccJerk-energy()-Y',
#  'fBodyAccJerk-energy()-Z',
#  'fBodyAccJerk-iqr()-X',
#  'fBodyAccJerk-iqr()-Y',
#  'fBodyAccJerk-iqr()-Z',
#  'fBodyAccJerk-entropy()-X',
#  'fBodyAccJerk-entropy()-Y',
#  'fBodyAccJerk-entropy()-Z',
#  'fBodyAccJerk-maxInds-X',
#  'fBodyAccJerk-maxInds-Y',
#  'fBodyAccJerk-maxInds-Z',
#  'fBodyAccJerk-meanFreq()-X',
#  'fBodyAccJerk-meanFreq()-Y',
#  'fBodyAccJerk-meanFreq()-Z',
#  'fBodyAccJerk-skewness()-X',
#  'fBodyAccJerk-kurtosis()-X',
#  'fBodyAccJerk-skewness()-Y',
#  'fBodyAccJerk-kurtosis()-Y',
#  'fBodyAccJerk-skewness()-Z',
#  'fBodyAccJerk-kurtosis()-Z',
#  'fBodyAccJerk-bandsEnergy()-1,8',
#  'fBodyAccJerk-bandsEnergy()-9,16',
#  'fBodyAccJerk-bandsEnergy()-17,24',
#  'fBodyAccJerk-bandsEnergy()-25,32',
#  'fBodyAccJerk-bandsEnergy()-33,40',
#  'fBodyAccJerk-bandsEnergy()-41,48',
#  'fBodyAccJerk-bandsEnergy()-49,56',
#  'fBodyAccJerk-bandsEnergy()-57,64',
#  'fBodyAccJerk-bandsEnergy()-1,16',
#  'fBodyAccJerk-bandsEnergy()-17,32',
#  'fBodyAccJerk-bandsEnergy()-33,48',
#  'fBodyAccJerk-bandsEnergy()-49,64',
#  'fBodyAccJerk-bandsEnergy()-1,24',
#  'fBodyAccJerk-bandsEnergy()-25,48',
#  'fBodyAccJerk-bandsEnergy()-1,8',
#  'fBodyAccJerk-bandsEnergy()-9,16',
#  'fBodyAccJerk-bandsEnergy()-17,24',
#  'fBodyAccJerk-bandsEnergy()-25,32',
#  'fBodyAccJerk-bandsEnergy()-33,40',
#  'fBodyAccJerk-bandsEnergy()-41,48',
#  'fBodyAccJerk-bandsEnergy()-49,56',
#  'fBodyAccJerk-bandsEnergy()-57,64',
#  'fBodyAccJerk-bandsEnergy()-1,16',
#  'fBodyAccJerk-bandsEnergy()-17,32',
#  'fBodyAccJerk-bandsEnergy()-33,48',
#  'fBodyAccJerk-bandsEnergy()-49,64',
#  'fBodyAccJerk-bandsEnergy()-1,24',
#  'fBodyAccJerk-bandsEnergy()-25,48',
#  'fBodyAccJerk-bandsEnergy()-1,8',
#  'fBodyAccJerk-bandsEnergy()-9,16',
#  'fBodyAccJerk-bandsEnergy()-17,24',
#  'fBodyAccJerk-bandsEnergy()-25,32',
#  'fBodyAccJerk-bandsEnergy()-33,40',
#  'fBodyAccJerk-bandsEnergy()-41,48',
#  'fBodyAccJerk-bandsEnergy()-49,56',
#  'fBodyAccJerk-bandsEnergy()-57,64',
#  'fBodyAccJerk-bandsEnergy()-1,16',
#  'fBodyAccJerk-bandsEnergy()-17,32',
#  'fBodyAccJerk-bandsEnergy()-33,48',
#  'fBodyAccJerk-bandsEnergy()-49,64',
#  'fBodyAccJerk-bandsEnergy()-1,24',
#  'fBodyAccJerk-bandsEnergy()-25,48',
#  'fBodyGyro-mean()-X',
#  'fBodyGyro-mean()-Y',
#  'fBodyGyro-mean()-Z',
#  'fBodyGyro-std()-X',
#  'fBodyGyro-std()-Y',
#  'fBodyGyro-std()-Z',
#  'fBodyGyro-mad()-X',
#  'fBodyGyro-mad()-Y',
#  'fBodyGyro-mad()-Z',
#  'fBodyGyro-max()-X',
#  'fBodyGyro-max()-Y',
#  'fBodyGyro-max()-Z',
#  'fBodyGyro-min()-X',
#  'fBodyGyro-min()-Y',
#  'fBodyGyro-min()-Z',
#  'fBodyGyro-sma()',
#  'fBodyGyro-energy()-X',
#  'fBodyGyro-energy()-Y',
#  'fBodyGyro-energy()-Z',
#  'fBodyGyro-iqr()-X',
#  'fBodyGyro-iqr()-Y',
#  'fBodyGyro-iqr()-Z',
#  'fBodyGyro-entropy()-X',
#  'fBodyGyro-entropy()-Y',
#  'fBodyGyro-entropy()-Z',
#  'fBodyGyro-maxInds-X',
#  'fBodyGyro-maxInds-Y',
#  'fBodyGyro-maxInds-Z',
#  'fBodyGyro-meanFreq()-X',
#  'fBodyGyro-meanFreq()-Y',
#  'fBodyGyro-meanFreq()-Z',
#  'fBodyGyro-skewness()-X',
#  'fBodyGyro-kurtosis()-X',
#  'fBodyGyro-skewness()-Y',
#  'fBodyGyro-kurtosis()-Y',
#  'fBodyGyro-skewness()-Z',
#  'fBodyGyro-kurtosis()-Z',
#  'fBodyGyro-bandsEnergy()-1,8',
#  'fBodyGyro-bandsEnergy()-9,16',
#  'fBodyGyro-bandsEnergy()-17,24',
#  'fBodyGyro-bandsEnergy()-25,32',
#  'fBodyGyro-bandsEnergy()-33,40',
#  'fBodyGyro-bandsEnergy()-41,48',
#  'fBodyGyro-bandsEnergy()-49,56',
#  'fBodyGyro-bandsEnergy()-57,64',
#  'fBodyGyro-bandsEnergy()-1,16',
#  'fBodyGyro-bandsEnergy()-17,32',
#  'fBodyGyro-bandsEnergy()-33,48',
#  'fBodyGyro-bandsEnergy()-49,64',
#  'fBodyGyro-bandsEnergy()-1,24',
#  'fBodyGyro-bandsEnergy()-25,48',
#  'fBodyGyro-bandsEnergy()-1,8',
#  'fBodyGyro-bandsEnergy()-9,16',
#  'fBodyGyro-bandsEnergy()-17,24',
#  'fBodyGyro-bandsEnergy()-25,32',
#  'fBodyGyro-bandsEnergy()-33,40',
#  'fBodyGyro-bandsEnergy()-41,48',
#  'fBodyGyro-bandsEnergy()-49,56',
#  'fBodyGyro-bandsEnergy()-57,64',
#  'fBodyGyro-bandsEnergy()-1,16',
#  'fBodyGyro-bandsEnergy()-17,32',
#  'fBodyGyro-bandsEnergy()-33,48',
#  'fBodyGyro-bandsEnergy()-49,64',
#  'fBodyGyro-bandsEnergy()-1,24',
#  'fBodyGyro-bandsEnergy()-25,48',
#  'fBodyGyro-bandsEnergy()-1,8',
#  'fBodyGyro-bandsEnergy()-9,16',
#  'fBodyGyro-bandsEnergy()-17,24',
#  'fBodyGyro-bandsEnergy()-25,32',
#  'fBodyGyro-bandsEnergy()-33,40',
#  'fBodyGyro-bandsEnergy()-41,48',
#  'fBodyGyro-bandsEnergy()-49,56',
#  'fBodyGyro-bandsEnergy()-57,64',
#  'fBodyGyro-bandsEnergy()-1,16',
#  'fBodyGyro-bandsEnergy()-17,32',
#  'fBodyGyro-bandsEnergy()-33,48',
#  'fBodyGyro-bandsEnergy()-49,64',
#  'fBodyGyro-bandsEnergy()-1,24',
#  'fBodyGyro-bandsEnergy()-25,48',
#  'fBodyAccMag-mean()',
#  'fBodyAccMag-std()',
#  'fBodyAccMag-mad()',
#  'fBodyAccMag-max()',
#  'fBodyAccMag-min()',
#  'fBodyAccMag-sma()',
#  'fBodyAccMag-energy()',
#  'fBodyAccMag-iqr()',
#  'fBodyAccMag-entropy()',
#  'fBodyAccMag-maxInds',
#  'fBodyAccMag-meanFreq()',
#  'fBodyAccMag-skewness()',
#  'fBodyAccMag-kurtosis()',
#  'fBodyBodyAccJerkMag-mean()',
#  'fBodyBodyAccJerkMag-std()',
#  'fBodyBodyAccJerkMag-mad()',
#  'fBodyBodyAccJerkMag-max()',
#  'fBodyBodyAccJerkMag-min()',
#  'fBodyBodyAccJerkMag-sma()',
#  'fBodyBodyAccJerkMag-energy()',
#  'fBodyBodyAccJerkMag-iqr()',
#  'fBodyBodyAccJerkMag-entropy()',
#  'fBodyBodyAccJerkMag-maxInds',
#  'fBodyBodyAccJerkMag-meanFreq()',
#  'fBodyBodyAccJerkMag-skewness()',
#  'fBodyBodyAccJerkMag-kurtosis()',
#  'fBodyBodyGyroMag-mean()',
#  'fBodyBodyGyroMag-std()',
#  'fBodyBodyGyroMag-mad()',
#  'fBodyBodyGyroMag-max()',
#  'fBodyBodyGyroMag-min()',
#  'fBodyBodyGyroMag-sma()',
#  'fBodyBodyGyroMag-energy()',
#  'fBodyBodyGyroMag-iqr()',
#  'fBodyBodyGyroMag-entropy()',
#  'fBodyBodyGyroMag-maxInds',
#  'fBodyBodyGyroMag-meanFreq()',
#  'fBodyBodyGyroMag-skewness()',
#  'fBodyBodyGyroMag-kurtosis()',
#  'fBodyBodyGyroJerkMag-mean()',
#  'fBodyBodyGyroJerkMag-std()',
#  'fBodyBodyGyroJerkMag-mad()',
#  'fBodyBodyGyroJerkMag-max()',
#  'fBodyBodyGyroJerkMag-min()',
#  'fBodyBodyGyroJerkMag-sma()',
#  'fBodyBodyGyroJerkMag-energy()',
#  'fBodyBodyGyroJerkMag-iqr()',
#  'fBodyBodyGyroJerkMag-entropy()',
#  'fBodyBodyGyroJerkMag-maxInds',
#  'fBodyBodyGyroJerkMag-meanFreq()',
#  'fBodyBodyGyroJerkMag-skewness()',
#  'fBodyBodyGyroJerkMag-kurtosis()',
#  'angle(tBodyAccMean,gravity)',
#  'angle(tBodyAccJerkMean),gravityMean)',
#  'angle(tBodyGyroMean,gravityMean)',
#  'angle(tBodyGyroJerkMean,gravityMean)',
#  'angle(X,gravityMean)',
#  'angle(Y,gravityMean)',
#  'angle(Z,gravityMean)']

# %% [markdown]
# Printing the names of Features.

# %%
# get the data from txt files to pandas dataFrame
X_train = pd.read_csv('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/train/X_train.txt', delim_whitespace=True, header=None)
X_train.columns = [features]
# add subject column to the dataframe
X_train['subject'] = pd.read_csv('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/train/y_train.txt', names=['Act_emp_Name'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Act_emp'] = y_train
train['Act_emp_Name'] = y_train_labels
train.sample(2)
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 3905           0.25393          0.005999         -0.144862         0.021592
# 3940           0.16124         -0.176107         -0.273415        -0.063225
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 3905         0.311753        -0.005996        -0.043990         0.317311
# 3940         0.240734         0.014431        -0.146736         0.263956
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 3905        -0.032743         0.284034  ...                    0.203000
# 3940         0.034280         0.191551  ...                   -0.030784
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 3905                             0.035041                        -0.790070
# 3940                            -0.218584                         0.812292
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 3905                             0.766140            -0.793221
# 3940                            -0.691817            -0.704059
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Act_emp  \
# 3905             0.214248             0.104248      19       1
# 3940             0.273685             0.124985      19       2
#
#           Act_emp_Name
# 3905           WALKING
# 3940  WALKING_UPSTAIRS
#
# [2 rows x 564 columns]

# %%
train.head()
# Out:
#   tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 0          0.288585         -0.020294         -0.132905        -0.995279
# 1          0.278419         -0.016411         -0.123520        -0.998245
# 2          0.279653         -0.019467         -0.113462        -0.995380
# 3          0.279174         -0.026201         -0.123283        -0.996091
# 4          0.276629         -0.016570         -0.115362        -0.998139
#
#   tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 0        -0.983111        -0.913526        -0.995112        -0.983185
# 1        -0.975300        -0.960322        -0.998807        -0.974914
# 2        -0.967187        -0.978944        -0.996520        -0.963668
# 3        -0.983403        -0.990675        -0.997099        -0.982750
# 4        -0.980817        -0.990482        -0.998321        -0.979672
#
#   tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 0        -0.923527        -0.934724  ...                   -0.112754
# 1        -0.957686        -0.943068  ...                    0.053477
# 2        -0.977469        -0.938692  ...                   -0.118559
# 3        -0.989302        -0.938692  ...                   -0.036788
# 4        -0.990441        -0.942469  ...                    0.123320
#
#   angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 0                             0.030400                        -0.464761
# 1                            -0.007435                        -0.732626
# 2                             0.177899                         0.100699
# 3                            -0.012892                         0.640011
# 4                             0.122542                         0.693578
#
#   angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 0                            -0.018446            -0.841247
# 1                             0.703511            -0.844788
# 2                             0.808529            -0.848933
# 3                            -0.485366            -0.848649
# 4                            -0.615971            -0.847865
#
#   angle(Y,gravityMean) angle(Z,gravityMean) subject Act_emp Act_emp_Name
# 0             0.179941            -0.058627       1       5     STANDING
# 1             0.180289            -0.054317       1       5     STANDING
# 2             0.180637            -0.049118       1       5     STANDING
# 3             0.181935            -0.047663       1       5     STANDING
# 4             0.185151            -0.043892       1       5     STANDING
#
# [5 rows x 564 columns]

# %%
X_train
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 0             0.288585         -0.020294         -0.132905        -0.995279
# 1             0.278419         -0.016411         -0.123520        -0.998245
# 2             0.279653         -0.019467         -0.113462        -0.995380
# 3             0.279174         -0.026201         -0.123283        -0.996091
# 4             0.276629         -0.016570         -0.115362        -0.998139
# ...                ...               ...               ...              ...
# 7347          0.299665         -0.057193         -0.181233        -0.195387
# 7348          0.273853         -0.007749         -0.147468        -0.235309
# 7349          0.273387         -0.017011         -0.045022        -0.218218
# 7350          0.289654         -0.018843         -0.158281        -0.219139
# 7351          0.351503         -0.012423         -0.203867        -0.269270
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 0           -0.983111        -0.913526        -0.995112        -0.983185
# 1           -0.975300        -0.960322        -0.998807        -0.974914
# 2           -0.967187        -0.978944        -0.996520        -0.963668
# 3           -0.983403        -0.990675        -0.997099        -0.982750
# 4           -0.980817        -0.990482        -0.998321        -0.979672
# ...               ...              ...              ...              ...
# 7347         0.039905         0.077078        -0.282301         0.043616
# 7348         0.004816         0.059280        -0.322552        -0.029456
# 7349        -0.103822         0.274533        -0.304515        -0.098913
# 7350        -0.111412         0.268893        -0.310487        -0.068200
# 7351        -0.087212         0.177404        -0.377404        -0.038678
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 0           -0.923527        -0.934724  ...                   -0.112754
# 1           -0.957686        -0.943068  ...                    0.053477
# 2           -0.977469        -0.938692  ...                   -0.118559
# 3           -0.989302        -0.938692  ...                   -0.036788
# 4           -0.990441        -0.942469  ...                    0.123320
# ...               ...              ...  ...                         ...
# 7347         0.060410         0.210795  ...                   -0.190437
# 7348         0.080585         0.117440  ...                    0.064907
# 7349         0.332584         0.043999  ...                    0.052806
# 7350         0.319473         0.101702  ...                   -0.101360
# 7351         0.229430         0.269013  ...                   -0.280088
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 0                                0.030400                        -0.464761
# 1                               -0.007435                        -0.732626
# 2                                0.177899                         0.100699
# 3                               -0.012892                         0.640011
# 4                                0.122542                         0.693578
# ...                                   ...                              ...
# 7347                             0.829718                         0.206972
# 7348                             0.875679                        -0.879033
# 7349                            -0.266724                         0.864404
# 7350                             0.700740                         0.936674
# 7351                            -0.007739                        -0.056088
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 0                               -0.018446            -0.841247
# 1                                0.703511            -0.844788
# 2                                0.808529            -0.848933
# 3                               -0.485366            -0.848649
# 4                               -0.615971            -0.847865
# ...                                   ...                  ...
# 7347                            -0.425619            -0.791883
# 7348                             0.400219            -0.771840
# 7349                             0.701169            -0.779133
# 7350                            -0.589479            -0.785181
# 7351                            -0.616956            -0.783267
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Act_emp  \
# 0                0.179941            -0.058627       1       5
# 1                0.180289            -0.054317       1       5
# 2                0.180637            -0.049118       1       5
# 3                0.181935            -0.047663       1       5
# 4                0.185151            -0.043892       1       5
# ...                   ...                  ...     ...     ...
# 7347             0.238604             0.049819      30       2
# 7348             0.252676             0.050053      30       2
# 7349             0.249145             0.040811      30       2
# 7350             0.246432             0.025339      30       2
# 7351             0.246809             0.036695      30       2
#
#           Act_emp_Name
# 0             STANDING
# 1             STANDING
# 2             STANDING
# 3             STANDING
# 4             STANDING
# ...                ...
# 7347  WALKING_UPSTAIRS
# 7348  WALKING_UPSTAIRS
# 7349  WALKING_UPSTAIRS
# 7350  WALKING_UPSTAIRS
# 7351  WALKING_UPSTAIRS
#
# [7352 rows x 564 columns]

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns = [features]
# add subject column to the dataframe
X_test['subject'] = pd.read_csv('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/test/y_test.txt', names=['Act_emp_Name'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Act_emp'] = y_test
test['Act_emp_Name'] = y_test_labels
test.sample(2)
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 2292          0.276331         -0.013232         -0.114941        -0.980905
# 4             0.274833         -0.027848         -0.129527        -0.993852
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 2292        -0.977037        -0.989890        -0.986290        -0.980007
# 4           -0.967445        -0.978295        -0.994111        -0.965953
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 2292        -0.989787        -0.906583  ...                   -0.068759
# 4           -0.977346        -0.938610  ...                   -0.002223
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 2292                             0.420896                         0.437746
# 4                               -0.040046                         0.736715
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 2292                            -0.464675             0.752773
# 4                               -0.118545            -0.692245
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Act_emp Act_emp_Name
# 2292            -0.540241            -0.446643      20       6       LAYING
# 4                0.290722            -0.073857       2       5     STANDING
#
# [2 rows x 564 columns]

# %% [markdown]
# 1. Getting the test data from text files and putting them in pandas dataframe.
# 2. Adding the **Subject** column from test data to the Dataframe.
# 3. Putting the Columns **Act_emp** and **Act_emp_Name** in a single dataframe.
# 4. Here **Act_emp** stands for the Activity Number that is being done by the employee and **Act_emp_Name** stands for the Activity performed by the employee.

# %%
test.head()
# Out:
#   tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 0          0.257178         -0.023285         -0.014654        -0.938404
# 1          0.286027         -0.013163         -0.119083        -0.975415
# 2          0.275485         -0.026050         -0.118152        -0.993819
# 3          0.270298         -0.032614         -0.117520        -0.994743
# 4          0.274833         -0.027848         -0.129527        -0.993852
#
#   tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 0        -0.920091        -0.667683        -0.952501        -0.925249
# 1        -0.967458        -0.944958        -0.986799        -0.968401
# 2        -0.969926        -0.962748        -0.994403        -0.970735
# 3        -0.973268        -0.967091        -0.995274        -0.974471
# 4        -0.967445        -0.978295        -0.994111        -0.965953
#
#   tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 0        -0.674302        -0.894088  ...                    0.006462
# 1        -0.945823        -0.894088  ...                   -0.083495
# 2        -0.963483        -0.939260  ...                   -0.034956
# 3        -0.968897        -0.938610  ...                   -0.017067
# 4        -0.977346        -0.938610  ...                   -0.002223
#
#   angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 0                             0.162920                        -0.825886
# 1                             0.017500                        -0.434375
# 2                             0.202302                         0.064103
# 3                             0.154438                         0.340134
# 4                            -0.040046                         0.736715
#
#   angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 0                             0.271151            -0.720009
# 1                             0.920593            -0.698091
# 2                             0.145068            -0.702771
# 3                             0.296407            -0.698954
# 4                            -0.118545            -0.692245
#
#   angle(Y,gravityMean) angle(Z,gravityMean) subject Act_emp Act_emp_Name
# 0             0.276801            -0.057978       2       5     STANDING
# 1             0.281343            -0.083898       2       5     STANDING
# 2             0.280083            -0.079346       2       5     STANDING
# 3             0.284114            -0.077108       2       5     STANDING
# 4             0.290722            -0.073857       2       5     STANDING
#
# [5 rows x 564 columns]

# %% [markdown]
# 1. These are the top 5 values from the test data.
# 2. .head() by defaults print the top 5 values from the given dataset.

# %%
print(train.shape,test.shape)
# Out:
# (7352, 564) (2947, 564)

# %% [markdown]
# *    .shape tells the shape of our test data.

# %%
print('Duplicates present in train: {}'.format(sum(train.duplicated())))
print('Duplicates present in test : {}'.format(sum(test.duplicated())))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2947: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# Duplicates present in train: 0
# Duplicates present in test : 0

# %%
print('{} NaN/Null values are present in train'.format(train.isnull().values.sum()))
print('{} NaN/Null values are present in test'.format(test.isnull().values.sum()))
# Out:
# 0 NaN/Null values are present in train
# 0 NaN/Null values are present in test

# %%
test.to_csv('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/train/csv_files/test.csv', index=False)
train.to_csv('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/train/csv_files/train.csv', index=False)

# %% [markdown]
# *   Converting both test and train TXT files to CSV(Comma Separated Values) file.

# %%
'/content/drive/MyDrive/UCI HAR Dataset-20221223T170042Z-001/UCI HAR Dataset/UCI HAR Dataset/test/csv_files/test.csv'
'/content/drive/MyDrive/UCI HAR Dataset-20221223T170042Z-001/UCI HAR Dataset/UCI HAR Dataset/train/csv_files/train.csv'
# Out:
# '/content/drive/MyDrive/UCI HAR Dataset-20221223T170042Z-001/UCI HAR Dataset/UCI HAR Dataset/train/csv_files/train.csv'

# %%
train = pd.read_csv('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/train/csv_files/train.csv')
test = pd.read_csv('C:/Users/Administrator/Downloads/docu3c/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/train/csv_files/test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %% [markdown]
# *   Train has 7352 rows and 564 columns
# *  Test has 2947 rows and 564 columns

# %%
print(train.columns)
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Act_emp',
#        'Act_emp_Name'],
#       dtype='object', length=564)

# %% [markdown]
# Now printing all the columns if train data

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9044/71913079.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[()]','')
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9044/71913079.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[-]', '')
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9044/71913079.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[,]','')
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Act_emp', 'Act_emp_Name'],
#       dtype='object', length=564)

# %% [markdown]
# 1. Removing all the extra symbols from the data and separating it by **' , '**
# 2. Printing the columns of test data.

# %%
train['subject'].unique()
# Out:
# array([ 1,  3,  5,  6,  7,  8, 11, 14, 15, 16, 17, 19, 21, 22, 23, 25, 26,
#        27, 28, 29, 30], dtype=int64)

# %%
import matplotlib as mlt
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_style('darkgrid')
plt.rcParams['font.family'] = 'sans-serif'

plt.figure(figsize=(20,10))
plt.title('Data of Employees', fontsize=20)
sns.countplot(x='subject',hue='Act_emp_Name', data = train)

plt.show()

# %% [markdown]
# 1. This plot has been plotted to keep a track of activities performed by the employees.
# 2. Also, this plot has been made to see if there is any imbalance in the data but after looking at this plot we can see that there is no imbalance in this data as same number of activities are being performed by the employees.

# %%
import plotly
import plotly.graph_objects as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot


# Plotting data
label_counts = train['Act_emp_Name'].value_counts()

# Get colors
n = label_counts.shape[0]
colormap = plt.get_cmap('cividis')
colors = [mlt.colors.to_hex(colormap(col)) for col in np.arange(0, 1.01, 1/(n-1))]

# Create plot
data = go.Bar(x = label_counts.index,
              y = label_counts,
              marker = dict(color = colors))

layout = go.Layout(title = 'Distribution of Names of Activity performed',
                   xaxis = dict(title = 'Act_emp_Name'),
                   yaxis = dict(title = 'Count'))

fig = go.Figure(data=[data], layout=layout)
fig.show()
#iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9044/2752631749.py in <module>
# ----> 1 import plotly
#       2 import plotly.graph_objects as go
#       3 from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#       4
#       5
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# This graph shows us the value of the activities performed by the Number of employees.

# %%
sns.set_palette("tab20", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='Act_emp_Name', height=5,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.960,12), xytext=(-0.5, 15), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3,rad=0.1",color="blue"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3,rad=0.1",color="blue"))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 1. This plot has been plotted to see the **Stationary Activities** and **Moving Activities** of the employees.
# 2. In this **tBodtAccMagmean** has been used to get a clear view of static and dynamic activities performed.
# 3. From this plot we can see that the **Stationary Activities** are Standing, Sitting and Laying and **Moving Activities** are Walking, Walking Downstairs and Walking Upstairs.

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Act_emp']==1]
df2 = train[train['Act_emp']==2]
df3 = train[train['Act_emp']==3]
df4 = train[train['Act_emp']==4]
df5 = train[train['Act_emp']==5]
df6 = train[train['Act_emp']==6]

plt.figure(figsize=(15,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.08, -0.2, 0.1, 20])
plt.legend(loc='center right')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'pink',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'black',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# * For getting a more clear view of Stationary Activities and Moving Activities the data points of them has been divided into different dataframes.

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Act_emp_Name', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='r')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The above box plot has been polotted to get a more clear understanding of Stationary and Moving activities.
# From this we understand that:-
# *   If **tAccMean** < -0.8 then Activities are either Standing, Sitting and Laying.
# *   If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# * If tAccMean > 0.0 then the Activity is WalkingDownstairs.

# %%
#Gravity Acceleration Position
sns.boxplot(x='Act_emp_Name', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# The position of Gravity Acceleration Position also matters as we can see that the value of Gravity Mean lies between 0 to 0.25 which means that:
# *   If at angleX, gravityMean > 0 then the activity performed is Laying.

# %%
sns.boxplot(x='Act_emp_Name', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 90)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='r')
plt.show()

# %% [markdown]
# The position of Gravity Acceleration Position also matters as we can see that the value of Gravity Mean lies at -0.2 which means that:
# *   If at angleY, gravityMean > -0.2 then the activities performed are Standing, Sitting, Walking Walking Upstairs and Walking Downstairs.

# %% [markdown]
# #Apply t-sne on dataset

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Making plot for t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="tab20",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        plt.show()
        print('Done')

# %% [markdown]
# * Applying t-sne on the data to know that how many activities are separable.

# %%
X_pre_tsne = train.drop(['subject', 'Act_emp','Act_emp_Name'], axis=1)
y_pre_tsne = train['Act_emp_Name']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.000s...
# [t-SNE] Computed neighbors for 7352 samples in 1.514s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.217s
# [t-SNE] Iteration 50: error = 124.7619171, gradient norm = 0.0277841 (50 iterations in 1.277s)
# [t-SNE] Iteration 100: error = 106.6927948, gradient norm = 0.0272680 (50 iterations in 0.802s)
# [t-SNE] Iteration 150: error = 100.5194626, gradient norm = 0.0196941 (50 iterations in 0.689s)
# [t-SNE] Iteration 200: error = 97.1870270, gradient norm = 0.0154476 (50 iterations in 0.745s)
# [t-SNE] Iteration 250: error = 94.9424133, gradient norm = 0.0155697 (50 iterations in 0.749s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 94.942413
# [t-SNE] Iteration 300: error = 4.1117306, gradient norm = 0.0015593 (50 iterations in 0.703s)
# [t-SNE] Iteration 350: error = 3.2052739, gradient norm = 0.0009949 (50 iterations in 0.680s)
# [t-SNE] Iteration 400: error = 2.7764447, gradient norm = 0.0007128 (50 iterations in 0.737s)
# [t-SNE] Iteration 450: error = 2.5126464, gradient norm = 0.0005643 (50 iterations in 0.749s)
# [t-SNE] Iteration 500: error = 2.3296063, gradient norm = 0.0004767 (50 iterations in 0.682s)
# [t-SNE] Iteration 550: error = 2.1917248, gradient norm = 0.0004155 (50 iterations in 0.685s)
# [t-SNE] Iteration 600: error = 2.0822771, gradient norm = 0.0003665 (50 iterations in 0.760s)
# [t-SNE] Iteration 650: error = 1.9925452, gradient norm = 0.0003349 (50 iterations in 0.654s)
# [t-SNE] Iteration 700: error = 1.9170865, gradient norm = 0.0003038 (50 iterations in 0.701s)
# [t-SNE] Iteration 750: error = 1.8520497, gradient norm = 0.0002790 (50 iterations in 0.709s)
# [t-SNE] Iteration 800: error = 1.7952162, gradient norm = 0.0002573 (50 iterations in 0.642s)
# [t-SNE] Iteration 850: error = 1.7452126, gradient norm = 0.0002409 (50 iterations in 0.809s)
# [t-SNE] Iteration 900: error = 1.7008098, gradient norm = 0.0002224 (50 iterations in 0.846s)
# [t-SNE] Iteration 950: error = 1.6607474, gradient norm = 0.0002090 (50 iterations in 0.845s)
# [t-SNE] Iteration 1000: error = 1.6244814, gradient norm = 0.0001998 (50 iterations in 0.691s)
# [t-SNE] KL divergence after 1000 iterations: 1.624481
# Done..
# Making plot for t-sne visualization..
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.007s...
# [t-SNE] Computed neighbors for 7352 samples in 1.259s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.031s
# [t-SNE] Iteration 50: error = 114.2338028, gradient norm = 0.0206622 (50 iterations in 2.508s)
# [t-SNE] Iteration 100: error = 98.4528809, gradient norm = 0.0151685 (50 iterations in 0.748s)
# [t-SNE] Iteration 150: error = 93.4167404, gradient norm = 0.0134877 (50 iterations in 0.689s)
# [t-SNE] Iteration 200: error = 91.3297119, gradient norm = 0.0068733 (50 iterations in 0.634s)
# [t-SNE] Iteration 250: error = 90.0969467, gradient norm = 0.0053754 (50 iterations in 0.686s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.096947
# [t-SNE] Iteration 300: error = 3.5782211, gradient norm = 0.0014605 (50 iterations in 0.627s)
# [t-SNE] Iteration 350: error = 2.8191624, gradient norm = 0.0007541 (50 iterations in 0.605s)
# [t-SNE] Iteration 400: error = 2.4385443, gradient norm = 0.0005280 (50 iterations in 0.665s)
# [t-SNE] Iteration 450: error = 2.2205007, gradient norm = 0.0004032 (50 iterations in 0.635s)
# [t-SNE] Iteration 500: error = 2.0750010, gradient norm = 0.0003355 (50 iterations in 0.732s)
# [t-SNE] Iteration 550: error = 1.9692914, gradient norm = 0.0002838 (50 iterations in 0.643s)
# [t-SNE] Iteration 600: error = 1.8879406, gradient norm = 0.0002459 (50 iterations in 0.634s)
# [t-SNE] Iteration 650: error = 1.8228111, gradient norm = 0.0002184 (50 iterations in 0.640s)
# [t-SNE] Iteration 700: error = 1.7689888, gradient norm = 0.0001962 (50 iterations in 0.647s)
# [t-SNE] Iteration 750: error = 1.7234303, gradient norm = 0.0001785 (50 iterations in 0.694s)
# [t-SNE] Iteration 800: error = 1.6843418, gradient norm = 0.0001668 (50 iterations in 0.642s)
# [t-SNE] Iteration 850: error = 1.6503294, gradient norm = 0.0001521 (50 iterations in 0.667s)
# [t-SNE] Iteration 900: error = 1.6203746, gradient norm = 0.0001433 (50 iterations in 0.646s)
# [t-SNE] Iteration 950: error = 1.5938448, gradient norm = 0.0001348 (50 iterations in 0.656s)
# [t-SNE] Iteration 1000: error = 1.5699575, gradient norm = 0.0001259 (50 iterations in 0.674s)
# [t-SNE] KL divergence after 1000 iterations: 1.569957
# Done..
# Making plot for t-sne visualization..
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.020s...
# [t-SNE] Computed neighbors for 7352 samples in 1.132s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.086s
# [t-SNE] Iteration 50: error = 105.7461243, gradient norm = 0.0219222 (50 iterations in 1.147s)
# [t-SNE] Iteration 100: error = 90.6502686, gradient norm = 0.0115430 (50 iterations in 0.830s)
# [t-SNE] Iteration 150: error = 87.3834991, gradient norm = 0.0060462 (50 iterations in 0.769s)
# [t-SNE] Iteration 200: error = 86.0988007, gradient norm = 0.0044520 (50 iterations in 0.783s)
# [t-SNE] Iteration 250: error = 85.3939819, gradient norm = 0.0032154 (50 iterations in 0.782s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.393982
# [t-SNE] Iteration 300: error = 3.1356044, gradient norm = 0.0013927 (50 iterations in 0.750s)
# [t-SNE] Iteration 350: error = 2.4907250, gradient norm = 0.0006526 (50 iterations in 0.700s)
# [t-SNE] Iteration 400: error = 2.1700144, gradient norm = 0.0004252 (50 iterations in 0.716s)
# [t-SNE] Iteration 450: error = 1.9848228, gradient norm = 0.0003151 (50 iterations in 0.744s)
# [t-SNE] Iteration 500: error = 1.8661816, gradient norm = 0.0002516 (50 iterations in 0.706s)
# [t-SNE] Iteration 550: error = 1.7826873, gradient norm = 0.0002094 (50 iterations in 0.774s)
# [t-SNE] Iteration 600: error = 1.7198721, gradient norm = 0.0001802 (50 iterations in 0.739s)
# [t-SNE] Iteration 650: error = 1.6705040, gradient norm = 0.0001589 (50 iterations in 0.719s)
# [t-SNE] Iteration 700: error = 1.6304650, gradient norm = 0.0001429 (50 iterations in 0.672s)
# [t-SNE] Iteration 750: error = 1.5976850, gradient norm = 0.0001293 (50 iterations in 0.730s)
# [t-SNE] Iteration 800: error = 1.5703704, gradient norm = 0.0001207 (50 iterations in 0.686s)
# [t-SNE] Iteration 850: error = 1.5469472, gradient norm = 0.0001113 (50 iterations in 0.725s)
# [t-SNE] Iteration 900: error = 1.5267569, gradient norm = 0.0001029 (50 iterations in 0.706s)
# [t-SNE] Iteration 950: error = 1.5091395, gradient norm = 0.0000970 (50 iterations in 0.715s)
# [t-SNE] Iteration 1000: error = 1.4934286, gradient norm = 0.0000908 (50 iterations in 0.750s)
# [t-SNE] KL divergence after 1000 iterations: 1.493429
# Done..
# Making plot for t-sne visualization..
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# [t-SNE] Computed neighbors for 7352 samples in 1.209s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.151s
# [t-SNE] Iteration 50: error = 97.2975616, gradient norm = 0.0211820 (50 iterations in 1.027s)
# [t-SNE] Iteration 100: error = 83.8319855, gradient norm = 0.0074847 (50 iterations in 0.829s)
# [t-SNE] Iteration 150: error = 81.9410248, gradient norm = 0.0040768 (50 iterations in 0.790s)
# [t-SNE] Iteration 200: error = 81.1782990, gradient norm = 0.0025637 (50 iterations in 0.800s)
# [t-SNE] Iteration 250: error = 80.7833557, gradient norm = 0.0020342 (50 iterations in 0.784s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.783356
# [t-SNE] Iteration 300: error = 2.6943443, gradient norm = 0.0013090 (50 iterations in 0.818s)
# [t-SNE] Iteration 350: error = 2.1592557, gradient norm = 0.0005762 (50 iterations in 0.836s)
# [t-SNE] Iteration 400: error = 1.9108486, gradient norm = 0.0003482 (50 iterations in 0.831s)
# [t-SNE] Iteration 450: error = 1.7650640, gradient norm = 0.0002481 (50 iterations in 0.853s)
# [t-SNE] Iteration 500: error = 1.6715734, gradient norm = 0.0001922 (50 iterations in 0.866s)
# [t-SNE] Iteration 550: error = 1.6076368, gradient norm = 0.0001590 (50 iterations in 0.867s)
# [t-SNE] Iteration 600: error = 1.5614399, gradient norm = 0.0001346 (50 iterations in 0.847s)
# [t-SNE] Iteration 650: error = 1.5263517, gradient norm = 0.0001188 (50 iterations in 0.883s)
# [t-SNE] Iteration 700: error = 1.4989998, gradient norm = 0.0001067 (50 iterations in 0.834s)
# [t-SNE] Iteration 750: error = 1.4770167, gradient norm = 0.0000974 (50 iterations in 0.764s)
# [t-SNE] Iteration 800: error = 1.4596038, gradient norm = 0.0000879 (50 iterations in 0.889s)
# [t-SNE] Iteration 850: error = 1.4453301, gradient norm = 0.0000846 (50 iterations in 0.814s)
# [t-SNE] Iteration 900: error = 1.4336091, gradient norm = 0.0000804 (50 iterations in 0.816s)
# [t-SNE] Iteration 950: error = 1.4240102, gradient norm = 0.0000757 (50 iterations in 0.785s)
# [t-SNE] Iteration 1000: error = 1.4157985, gradient norm = 0.0000758 (50 iterations in 0.835s)
# [t-SNE] KL divergence after 1000 iterations: 1.415799
# Done..
# Making plot for t-sne visualization..
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# [t-SNE] Computed neighbors for 7352 samples in 1.223s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.364s
# [t-SNE] Iteration 50: error = 85.5430374, gradient norm = 0.0300886 (50 iterations in 1.423s)
# [t-SNE] Iteration 100: error = 75.9600830, gradient norm = 0.0043476 (50 iterations in 1.266s)
# [t-SNE] Iteration 150: error = 74.8562164, gradient norm = 0.0026116 (50 iterations in 1.200s)
# [t-SNE] Iteration 200: error = 74.3974380, gradient norm = 0.0016378 (50 iterations in 1.165s)
# [t-SNE] Iteration 250: error = 74.1798019, gradient norm = 0.0011462 (50 iterations in 1.135s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.179802
# [t-SNE] Iteration 300: error = 2.1676841, gradient norm = 0.0012045 (50 iterations in 1.248s)
# [t-SNE] Iteration 350: error = 1.7677636, gradient norm = 0.0004861 (50 iterations in 1.173s)
# [t-SNE] Iteration 400: error = 1.5983286, gradient norm = 0.0002855 (50 iterations in 1.200s)
# [t-SNE] Iteration 450: error = 1.5043772, gradient norm = 0.0001908 (50 iterations in 1.180s)
# [t-SNE] Iteration 500: error = 1.4441798, gradient norm = 0.0001423 (50 iterations in 1.100s)
# [t-SNE] Iteration 550: error = 1.4021899, gradient norm = 0.0001174 (50 iterations in 1.133s)
# [t-SNE] Iteration 600: error = 1.3724935, gradient norm = 0.0000979 (50 iterations in 1.283s)
# [t-SNE] Iteration 650: error = 1.3513405, gradient norm = 0.0000883 (50 iterations in 1.233s)
# [t-SNE] Iteration 700: error = 1.3360474, gradient norm = 0.0000805 (50 iterations in 1.131s)
# [t-SNE] Iteration 750: error = 1.3249086, gradient norm = 0.0000740 (50 iterations in 1.134s)
# [t-SNE] Iteration 800: error = 1.3164562, gradient norm = 0.0000682 (50 iterations in 1.182s)
# [t-SNE] Iteration 850: error = 1.3096037, gradient norm = 0.0000646 (50 iterations in 1.135s)
# [t-SNE] Iteration 900: error = 1.3040401, gradient norm = 0.0000622 (50 iterations in 1.124s)
# [t-SNE] Iteration 950: error = 1.2992361, gradient norm = 0.0000610 (50 iterations in 1.075s)
# [t-SNE] Iteration 1000: error = 1.2952611, gradient norm = 0.0000581 (50 iterations in 1.113s)
# [t-SNE] KL divergence after 1000 iterations: 1.295261
# Done..
# Making plot for t-sne visualization..
# Done

# %% [markdown]
# After applying t-sne on 561 features, TSNE clusters are visible in which it can be clearly seen that activities like "Laying", "Walking", "Walking Upstairs", "Walking Downstairs" are clearly visible and separated as compared to "Satnding" and "Sitting".
